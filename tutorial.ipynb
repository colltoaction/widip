# %% [markdown]
# The following example shows several features of the YAML language combined into a single Wiring Diagram.

# %%
from titi.loader import repl_read

repl_read("""
- a: { b, c: {} }
- !d
  e: f
  {}: g
  {h, i}: ""
- !j [k, l]
""").draw()
