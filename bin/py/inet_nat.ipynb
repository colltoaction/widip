# %%
import networkx as nx
from inet import *

# %%
inet = nx.MultiDiGraph()
o = inet_zero(inet)
s = inet_succ(inet)
inet_draw(inet)

# %%
inet_apply(inet, (o, 0), (s, 0))
inet_draw(inet)

# %%
annihilate_concon_or_dupdup(inet)
inet_draw(inet)

# %%
annihilate_concon_or_dupdup(inet)
inet_draw(inet)

# %%
annihilate_concon_or_dupdup(inet)
inet_draw(inet)
